# %%
pip install bluemist

# %%
from sklearn import datasets

from bluemist.environment import initialize
from bluemist.preprocessing import preprocess_data
from bluemist.regression import train_test_evaluate

# %%
initialize()
data = datasets.load_diabetes(as_frame=True)
# Out:
# ██████╗ ██╗     ██╗   ██╗███████╗███╗   ███╗██╗███████╗████████╗     █████╗ ██╗
# ██╔══██╗██║     ██║   ██║██╔════╝████╗ ████║██║██╔════╝╚══██╔══╝    ██╔══██╗██║
# ██████╔╝██║     ██║   ██║█████╗  ██╔████╔██║██║███████╗   ██║       ███████║██║
# ██╔══██╗██║     ██║   ██║██╔══╝  ██║╚██╔╝██║██║╚════██║   ██║       ██╔══██║██║
# ██████╔╝███████╗╚██████╔╝███████╗██║ ╚═╝ ██║██║███████║   ██║       ██║  ██║██║
#                                 (version 0.1.1)
#
# Bluemist path :: /home/shashank-agrawal/PycharmProjects/bluemist-ai/bluemist
# System platform :: posix, Linux, 5.19.0-31-generic, linux-x86_64, ('64bit', 'ELF')

# %%
# Categorical encoding using OneHotEncoder
X_train, X_test, y_train, y_test = preprocess_data(data.frame, 
                                                   target_variable='target', 
                                                   test_size=0.25, 
                                                   categorical_features=['sex'], 
                                                   categorical_encoder='OneHotEncoder')

# %%
# Train and compare models
train_test_evaluate(X_train, X_test, y_train, y_test)
# Out:
# Training TweedieRegressor: 100%|██████████| 46/46 [00:20<00:00,  2.25it/s]
# <style type="text/css">
# #T_51684_row20_col0, #T_51684_row20_col1, #T_51684_row20_col2 {
#   background-color: green;
# }
# #T_51684_row31_col0, #T_51684_row31_col1, #T_51684_row31_col2 {
#   background-color: yellow;
# }
# </style>
# <table id="T_51684">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51684_level0_col0" class="col_heading level0 col0" >mean_absolute_error</th>
#       <th id="T_51684_level0_col1" class="col_heading level0 col1" >mean_squared_error</th>
#       <th id="T_51684_level0_col2" class="col_heading level0 col2" >r2_score</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Estimator</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51684_level0_row0" class="row_heading level0 row0" >ARDRegression</th>
#       <td id="T_51684_row0_col0" class="data row0 col0" >40.416720</td>
#       <td id="T_51684_row0_col1" class="data row0 col1" >2539.892199</td>
#       <td id="T_51684_row0_col2" class="data row0 col2" >0.539934</td>
#     </tr>
#     <tr>
#       <th id="T_51684_level0_row1" class="row_heading level0 row1" >AdaBoostRegressor</th>
#       <td id="T_51684_row1_col0" class="data row1 col0" >43.100757</td>
#       <td id="T_51684_row1_col1" class="data row1 col1" >2661.566464</td>
#       <td id="T_51684_row1_col2" class="data row1 col2" >0.517894</td>
#     </tr>
#     <tr>
#       <th id="T_51684_level0_row2" class="row_heading level0 row2" >BaggingRegressor</th>
#       <td id="T_51684_row2_col0" class="data row2 col0" >44.149550</td>
#       <td id="T_51684_row2_col1" class="data row2 col1" >3154.440180</td>
#       <td id="T_51684_row2_col2" class="data row2 col2" >0.428617</td>
#     </tr>
#     <tr>
#       <th id="T_51684_level0_row3" class="row_heading level0 row3" >BayesianRidge</th>
#       <td id="T_51684_row3_col0" class="data row3 col0" >40.212992</td>
#       <td id="T_51684_row3_col1" class="data row3 col1" >2514.053489</td>
#       <td id="T_51684_row3_col2" class="data row3 col2" >0.544614</td>
#     </tr>
#     <tr>
#       <th id="T_51684_level0_row4" class="row_heading level0 row4" >CCA</th>
#       <td id="T_51684_row4_col0" class="data row4 col0" >41.354237</td>
#       <td id="T_51684_row4_col1" class="data row4 col1" >2635.135043</td>
#       <td id="T_51684_row4_col2" class="data row4 col2" >0.522682</td>
#     </tr>
#     <tr>
#       <th id="T_51684_level0_row5" class="row_heading level0 row5" >DecisionTreeRegressor</th>
#       <td id="T_51684_row5_col0" class="data row5 col0" >56.900901</td>
#       <td id="T_51684_row5_col1" class="data row5 col1" >5374.414414</td>
#       <td id="T_51684_row5_col2" class="data row5 col2" >0.026500</td>
#     </tr>
#     <tr>
#       <th id="T_51684_level0_row6" class="row_heading level0 row6" >DummyRegressor</th>
#       <td id="T_51684_row6_col0" class="data row6 col0" >64.379549</td>
#       <td id="T_51684_row6_col1" class="data row6 col1" >5633.249976</td>
#       <td id="T_51684_row6_col2" class="data row6 col2" >-0.020385</td>
#     </tr>
#     <tr>
#       <th id="T_51684_level0_row7" class="row_heading level0 row7" >ElasticNet</th>
#       <td id="T_51684_row7_col0" class="data row7 col0" >41.057118</td>
#       <td id="T_51684_row7_col1" class="data row7 col1" >2574.845001</td>
#       <td id="T_51684_row7_col2" class="data row7 col2" >0.533603</td>
#     </tr>
#     <tr>
#       <th id="T_51684_level0_row8" class="row_heading level0 row8" >ElasticNetCV</th>
#       <td id="T_51684_row8_col0" class="data row8 col0" >40.079874</td>
#       <td id="T_51684_row8_col1" class="data row8 col1" >2498.791794</td>
#       <td id="T_51684_row8_col2" class="data row8 col2" >0.547379</td>
#     </tr>
#     <tr>
#       <th id="T_51684_level0_row9" class="row_heading level0 row9" >ExtraTreeRegressor</th>
#       <td id="T_51684_row9_col0" class="data row9 col0" >58.009009</td>
#       <td id="T_51684_row9_col1" class="data row9 col1" >5429.738739</td>
#       <td id="T_51684_row9_col2" class="data row9 col2" >0.016479</td>
#     </tr>
#     <tr>
#       <th id="T_51684_level0_row10" class="row_heading level0 row10" >ExtraTreesRegressor</th>
#       <td id="T_51684_row10_col0" class="data row10 col0" >44.111712</td>
#       <td id="T_51684_row10_col1" class="data row10 col1" >2942.928463</td>
#       <td id="T_51684_row10_col2" class="data row10 col2" >0.466930</td>
#     </tr>
#     <tr>
#       <th id="T_51684_level0_row11" class="row_heading level0 row11" >GammaRegressor</th>
#       <td id="T_51684_row11_col0" class="data row11 col0" >43.628441</td>
#       <td id="T_51684_row11_col1" class="data row11 col1" >2773.745354</td>
#       <td id="T_51684_row11_col2" class="data row11 col2" >0.497575</td>
#     </tr>
#     <tr>
#       <th id="T_51684_level0_row12" class="row_heading level0 row12" >GaussianProcessRegressor</th>
#       <td id="T_51684_row12_col0" class="data row12 col0" >69.158708</td>
#       <td id="T_51684_row12_col1" class="data row12 col1" >8226.874356</td>
#       <td id="T_51684_row12_col2" class="data row12 col2" >-0.490184</td>
#     </tr>
#     <tr>
#       <th id="T_51684_level0_row13" class="row_heading level0 row13" >GradientBoostingRegressor</th>
#       <td id="T_51684_row13_col0" class="data row13 col0" >44.355369</td>
#       <td id="T_51684_row13_col1" class="data row13 col1" >2930.840446</td>
#       <td id="T_51684_row13_col2" class="data row13 col2" >0.469119</td>
#     </tr>
#     <tr>
#       <th id="T_51684_level0_row14" class="row_heading level0 row14" >HistGradientBoostingRegressor</th>
#       <td id="T_51684_row14_col0" class="data row14 col0" >44.025402</td>
#       <td id="T_51684_row14_col1" class="data row14 col1" >3100.822564</td>
#       <td id="T_51684_row14_col2" class="data row14 col2" >0.438329</td>
#     </tr>
#     <tr>
#       <th id="T_51684_level0_row15" class="row_heading level0 row15" >HuberRegressor</th>
#       <td id="T_51684_row15_col0" class="data row15 col0" >41.777778</td>
#       <td id="T_51684_row15_col1" class="data row15 col1" >2698.279586</td>
#       <td id="T_51684_row15_col2" class="data row15 col2" >0.511244</td>
#     </tr>
#     <tr>
#       <th id="T_51684_level0_row16" class="row_heading level0 row16" >KNeighborsRegressor</th>
#       <td id="T_51684_row16_col0" class="data row16 col0" >44.554955</td>
#       <td id="T_51684_row16_col1" class="data row16 col1" >3050.001441</td>
#       <td id="T_51684_row16_col2" class="data row16 col2" >0.447535</td>
#     </tr>
#     <tr>
#       <th id="T_51684_level0_row17" class="row_heading level0 row17" >KernelRidge</th>
#       <td id="T_51684_row17_col0" class="data row17 col0" >40.495299</td>
#       <td id="T_51684_row17_col1" class="data row17 col1" >2551.940065</td>
#       <td id="T_51684_row17_col2" class="data row17 col2" >0.537752</td>
#     </tr>
#     <tr>
#       <th id="T_51684_level0_row18" class="row_heading level0 row18" >Lars</th>
#       <td id="T_51684_row18_col0" class="data row18 col0" >40.592790</td>
#       <td id="T_51684_row18_col1" class="data row18 col1" >2574.239406</td>
#       <td id="T_51684_row18_col2" class="data row18 col2" >0.533712</td>
#     </tr>
#     <tr>
#       <th id="T_51684_level0_row19" class="row_heading level0 row19" >LarsCV</th>
#       <td id="T_51684_row19_col0" class="data row19 col0" >40.163342</td>
#       <td id="T_51684_row19_col1" class="data row19 col1" >2510.877326</td>
#       <td id="T_51684_row19_col2" class="data row19 col2" >0.545190</td>
#     </tr>
#     <tr>
#       <th id="T_51684_level0_row20" class="row_heading level0 row20" >Lasso</th>
#       <td id="T_51684_row20_col0" class="data row20 col0" >39.880023</td>
#       <td id="T_51684_row20_col1" class="data row20 col1" >2486.877642</td>
#       <td id="T_51684_row20_col2" class="data row20 col2" >0.549537</td>
#     </tr>
#     <tr>
#       <th id="T_51684_level0_row21" class="row_heading level0 row21" >LassoCV</th>
#       <td id="T_51684_row21_col0" class="data row21 col0" >40.135980</td>
#       <td id="T_51684_row21_col1" class="data row21 col1" >2508.631202</td>
#       <td id="T_51684_row21_col2" class="data row21
